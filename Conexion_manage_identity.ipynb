# %%
df= spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://raw@adlsproyecto1005.dfs.core.windows.net/Productos.csv")
df.display()

# %%
df.write.mode("overwrite").save("abfss://raw@adlsproyecto1005.dfs.core.windows.net/data/out")

# %%
df.write.mode("overwrite").save("abfss://bronze@adlsproyecto1005.dfs.core.windows.net/data/out")

# %%
spark.conf.set("fs.azure.account.key.adlsproyecto1005.dfs.core.windows.net", "<your-storage-account-key>")df= spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://silver@adlsproyecto1005.dfs.core.windows.net/data/Mascotas.csv")

df.display()

# %%
df= spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("abfss://raw@adlsproyecto1005.dfs.core.windows.net/Mascotas.csv")
df.display()
